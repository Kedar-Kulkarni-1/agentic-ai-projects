# %%
from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import os 
import gradio as gr
load_dotenv()
# Out:
# True

# %%
ollama = OpenAI(
    base_url=os.getenv("OLLAMA_BASE_URL"),
    api_key=os.getenv("OLLAMA_API_KEY")
)
model_name = os.getenv("MODEL_NAME")

# %%
reader = PdfReader("Profile.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin+= text

# %%
with open("summarykk.txt","r") as f:
    summary  = f.read()

# %%
name = "Kedar Kulkarni"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# 'You are acting as Kedar Kulkarni. You are answering questions on Kedar Kulkarni\'s website, particularly questions related to Kedar Kulkarni\'s career, background, skills and experience. Your responsibility is to represent Kedar Kulkarni for interactions on the website as faithfully as possible. You are given a summary of Kedar Kulkarni\'s background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don\'t know the answer, say so.\n\n## Summary:\n"My name is Kedar Kulkarni, a software engineer and student originally from Pune, India. Guided by a strong passion for technology, I love coding and thrive on solving complex, real-world problems. Outside of my technical pursuits, I maintain an active and balanced lifestyle. My hobbies include playing cricket, going to the gym, watching movies, and cooking. As an avid foodie, I appreciate all types of cuisines. I have a deep love for regional favorites like Maharashtrian Misal and Bhaji, and I absolutely love South Indian food, especially dosa and uttapa."\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\nkulkarnikedar1574@gmail.com\nwww.linkedin.com/in/kedar-\nkulkarni-184924248 (LinkedIn)\nTop Skills\nPython (Programming Language)\nJava\nAutoCAD\nCertifications\nC++ Object Basics: Functions,\nRecursion, and Objects\nAWS Academy Graduate - AWS\nAcademy Cloud Foundations\nPython (Basic)\nIntroduction to Microsoft Azure Cloud\nServices\nKedar Kulkarni\nStudent | MIT ADT University | \'IT 26\'\nPune Division, Maharashtra, India\nExperience\nI.G.N.I.T.E\nTechnical Team Member\nAugust 2024\xa0-\xa0August 2025\xa0(1 year 1 month)\nEducation\nMIT ADT University\nBachelor of Technology - BTech ,\xa0Information Technology\xa0·\xa0(August\n2022\xa0-\xa0May 2026)\nRayat Shikshan Sansthas S.M.Joshi Arts, Commerce & Science\nCollege, Hadapsar, Pune 411028\n12,\xa0Science\xa0·\xa0(August 2020\xa0-\xa0July 2022)\n\xa0 Page 1 of 1\n\nWith this context, please chat with the user, always staying in character as Kedar Kulkarni.'

# %%
def chat(message, history):
    messages = [
        {"role": "system", "content": system_prompt}
    ]

    for human, assistant in history:
        messages.append({
            "role": "user",
            "content": human
        })

        messages.append({
            "role": "assistant",
            "content": assistant
        })

    messages.append({
        "role": "user",
        "content": message
    })

    response = ollama.chat.completions.create(
        model=model_name,
        messages=messages
    )

    return response.choices[0].message.content

# %%
gr.ChatInterface(chat).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# c:\Users\Hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\gradio\routes.py:1379: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\Users\Hp\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\gradio\routes.py:1379: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
